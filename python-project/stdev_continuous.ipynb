# %% [markdown]
# # Purpose
#
# The purpose of this notebook is the estiate the standard deviation values from the JSON results files and print them in Latex table format (for the supplementary material).

# %%
run = 1
numberOfFolds = 10

data = [
        "iris", 
        "buddymove", 
        "yeast", 
        "glass", 
        "ilpd", 
        "alcohol", 
        "wine", 
        "leaf", 
        "nba", 
        "vehicle", 
        "wdbc", 
        "ionosphere", 
        "waveform", 
        "100_plants", 
        "geo_music"
       ]

methods = [
           "KDE",
           "GS", 
           "GEAST", 
           "MSPN", 
           "IL",
           "CIL_1", 
           "CIL_10",
          ]

base_directory_path = "../results/run_" + str(run) + "/continuous/"

# %%
import json
import statistics as stats
    
for dataName in data:
    
    print("\n" + dataName)
    string_to_show = ""
    
    for methodName in methods:
        directoryName = dataName + "/" + str(numberOfFolds) + "_folds/" + methodName + "/"
        jsonName = dataName + "_results_" + methodName + ".json"
        fullPath = base_directory_path + directoryName + jsonName
        test_ll = []
        learning_time = []
        
        try:
            with open(fullPath) as json_file:
                    jsonData = json.load(json_file)
                    foldsData = jsonData["folds"]
                    for i in range(1,11):
                        test_ll.append(foldsData["fold_"+str(i)]["test_LL"])
                        learning_time.append(foldsData["fold_"+str(i)]["learning_time"])

                    mean_ll = stats.mean(test_ll)
                    stdev_ll = stats.stdev(test_ll)
                    mean_time = stats.mean(learning_time)/1000
                    stdev_time = stats.stdev(learning_time)/1000

                    string_to_show = string_to_show + str("%0.2f" % mean_time) + " & " + str("%0.2f" % stdev_time) + " & "
                    #string_to_show = string_to_show + str("%0.2f" % mean_time) + " & "
            
        except:
            string_to_show = string_to_show + "\multicolumn{2}{c|}{- - -}" + " & "
            #string_to_show = string_to_show + "$---$" + " & "
    
    print(string_to_show)
# Out:
# iris
# 0.00 & 0.00 & 3.34 & 0.68 & 12.93 & 0.46 & 1.28 & 0.23 & 0.63 & 0.03 & 0.39 & 0.17 & 0.77 & 0.03 &
#
# buddymove
# 0.00 & 0.00 & 25.67 & 4.56 & 213.78 & 112.87 & 4.48 & 1.03 & 2.80 & 0.09 & 0.58 & 0.15 & 2.54 & 0.19 &
#
# yeast
# 0.08 & 0.01 & 251.19 & 45.46 & 1540.01 & 294.14 & 22.80 & 6.11 & 29.49 & 0.20 & 4.15 & 0.27 & 15.24 & 0.19 &
#
# glass
# 0.01 & 0.00 & 59.03 & 6.30 & 486.43 & 73.01 & 9.85 & 2.11 & 10.88 & 1.53 & 0.65 & 0.18 & 3.99 & 1.75 &
#
# ilpd
# 0.02 & 0.00 & 442.72 & 44.47 & 1757.13 & 490.96 & 15.89 & 2.50 & 43.16 & 2.12 & 2.49 & 0.79 & 29.00 & 3.09 &
#
# alcohol
# 0.00 & 0.00 & 76.59 & 14.25 & 316.98 & 68.85 & 5.36 & 1.43 & 6.46 & 1.16 & 1.07 & 0.36 & 3.13 & 0.34 &
#
# wine
# 0.01 & 0.00 & 126.85 & 22.93 & 795.98 & 145.86 & 13.89 & 2.21 & 21.59 & 1.60 & 0.94 & 0.39 & 4.40 & 0.52 &
#
# leaf
# 0.02 & 0.00 & 289.41 & 23.30 & 3941.66 & 420.50 & 9.76 & 0.74 & 61.19 & 4.15 & 0.59 & 0.17 & 12.77 & 2.44 &
#
# nba
# 0.03 & 0.00 & 2336.86 & 240.13 & 13608.33 & 835.63 & 59.87 & 13.16 & 257.69 & 9.89 & 5.61 & 2.50 & 49.60 & 12.67 &
#
# vehicle
# 0.07 & 0.00 & 7198.36 & 3168.92 & 74520.49 & 11262.00 & 109.92 & 17.08 & 510.65 & 6.29 & 11.71 & 1.53 & 116.55 & 4.18 &
#
# wdbc
# 0.08 & 0.02 & 9582.42 & 3472.38 & 50784.86 & 3315.22 & 52.60 & 1.43 & 2436.78 & 26.62 & 8.90 & 1.61 & 57.90 & 4.24 &
#
# ionosphere
# 0.03 & 0.00 & 4231.51 & 629.04 & \multicolumn{2}{c|}{- - -} & 69.90 & 6.78 & 1433.53 & 86.14 & 3.59 & 0.79 & 46.41 & 5.76 &
#
# waveform
# 3.31 & 0.14 & \multicolumn{2}{c|}{- - -} & \multicolumn{2}{c|}{- - -} & 17.72 & 3.90 & 45831.88 & 1964.74 & 383.15 & 115.27 & 1314.81 & 244.66 &
#
# 100_plants
# 0.68 & 0.02 & 27992.68 & 1072.39 & \multicolumn{2}{c|}{- - -} & 604.52 & 19.70 & 6936.40 & 1244.92 & 61.20 & 6.49 & 58.20 & 7.41 &
#
# geo_music
# 0.37 & 0.01 & \multicolumn{2}{c|}{- - -} & \multicolumn{2}{c|}{- - -} & 724.22 & 34.93 & 102689.35 & 3440.98 & 79.11 & 11.93 & 2186.30 & 112.17 &
